# %% [markdown]
# <a href="https://colab.research.google.com/github/hajeong67/nlp_LoRA/blob/main/nlp_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers accelerate datasets peft trl bitsandbytes wandb
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.2)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (1.1.1)
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Collecting trl
#   Downloading trl-0.12.1-py3-none-any.whl.metadata (10 kB)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (0.18.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.5.1+cu121)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.10)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from trl) (13.9.4)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (4.25.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.18.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (75.1.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /usr/local/lib/python3.10/dist-packages (from wandb) (4.12.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->trl) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->trl) (0.1.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (3.0.2)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 9.4 MB/s eta 0:00:00
# Downloading trl-0.12.1-py3-none-any.whl (310 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.9/310.9 kB 9.6 MB/s eta 0:00:00
# Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl (122.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 6.1 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.9 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 15.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.4 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.7 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, bitsandbytes, datasets, trl
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed bitsandbytes-0.44.1 datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 trl-0.12.1 xxhash-3.5.0

# %% [markdown]
# # 라이브러리 install

# %%
import os
from dataclasses import dataclass, field
from typing import Optional
import re

import torch
import sys
from accelerate import Accelerator
from datasets import load_dataset, Dataset
from peft import AutoPeftModelForCausalLM, LoraConfig
from tqdm import tqdm
from transformers import (
    HfArgumentParser,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    TextStreamer,
    logging as hf_logging,
)
import logging
from trl import SFTTrainer, SFTConfig

from trl.trainer import ConstantLengthDataset

# %% [markdown]
# # 모델 설정

# %%
base_model_id = "meta-llama/Llama-3.2-1B-Instruct"
device_map = "cuda"
torch_dtype = torch.bfloat16
output_dir = "./llama-order-analysis"
dataset_name = "./llm-modeling-lab.jsonl"
seq_length = 512

# %% [markdown]
# # 토크나이저 설정

# %%
from huggingface_hub import login

# Hugging Face 토큰 발급
login(token="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")

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(base_model_id)
tokenizer.padding_side = "right"
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/54.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]

# %% [markdown]
# # 양자화 설정

# %%
from transformers import BitsAndBytesConfig

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16,
)

# %% [markdown]
# # 모델 로딩

# %%
from transformers import AutoModelForCausalLM

base_model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto"
)
base_model.config.use_cache = False
# Out:
# config.json:   0%|          | 0.00/877 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %% [markdown]
# # 패딩 토큰 설정

# %%
if getattr(tokenizer, "pad_token", None) is None:
    tokenizer.pad_token = tokenizer.eos_token
    tokenizer.pad_token_id = tokenizer.eos_token_id
if base_model.config.pad_token_id != tokenizer.pad_token_id:
    base_model.config.pad_token_id = tokenizer.pad_token_id

# %% [markdown]
# # 데이터셋 로딩 및 전처리

# %%
from datasets import Dataset

# 데이터셋 로딩
full_dataset = Dataset.from_json(path_or_paths=dataset_name)

# 학습용 2,800개/ 검증용 200개 분리
train_dataset = full_dataset.select(range(2800))
val_dataset = full_dataset.select(range(2800, 3000))

print(f"Training dataset size: {len(train_dataset)}")
print(f"Validation dataset size: {len(val_dataset)}")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Training dataset size: 2800
# Validation dataset size: 200

# %% [markdown]
# # 학습설정

# %% [markdown]
# 1. LoRA 설정

# %%
from peft import LoraConfig

peft_config = LoraConfig(
    r=8,  # 랭크 설정
    lora_alpha=32,  # LoRA 학습률 스케일링 계수
    target_modules=["q_proj", "v_proj"],  # 학습 대상 모듈
    lora_dropout=0.05,  # 드롭아웃 비율
    bias="none",  # 바이어스 설정
    task_type="CAUSAL_LM",  # 작업 유형 설정
)

# %% [markdown]
# 2. 학습 설정

# %%
from trl import SFTConfig

sft_config = SFTConfig(
    output_dir=output_dir,  # 결과가 저장될 디렉터리
    per_device_train_batch_size=2,  # 각 GPU/장치당 학습 배치 크기
    gradient_accumulation_steps=4,  # gradient accumulation 단계 수
    max_steps=100,  # 학습 최대 단계 수
    optim="paged_adamw_32bit",  # 옵티마이저 설정
    logging_steps=20,  # 로깅 빈도
    save_strategy="steps",  # 체크포인트 저장 전략
    save_steps=100,  # 체크포인트 저장 빈도
    save_total_limit=2,  # 저장할 체크포인트 개수 제한
    max_seq_length=seq_length,  # 입력 시퀀스의 최대 길이
    report_to="none",  # 로깅 도구 설정
    run_name="llama-fine-tuning"  # 실험 이름 설정
)

# %% [markdown]
# 3. Trainer 설정

# %%
from trl import SFTTrainer

trainer = SFTTrainer(
    model=base_model,  # 학습할 모델
    train_dataset=train_dataset,  # 학습 데이터셋
    eval_dataset=val_dataset,  # 검증 데이터셋
    peft_config=peft_config,  # LoRA 설정
    tokenizer=tokenizer,  # 토크나이저
    args=sft_config  # 학습 설정
)
# Out:
# Map:   0%|          | 0/2800 [00:00<?, ? examples/s]
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs

# %% [markdown]
# 4. 모델 학습 시작

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 01:32, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>20</td>
#       <td>5.975600</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>5.787500</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>5.631300</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>5.469400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>5.441800</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=100, training_loss=5.661101150512695, metrics={'train_runtime': 95.179, 'train_samples_per_second': 8.405, 'train_steps_per_second': 1.051, 'total_flos': 148308739645440.0, 'train_loss': 5.661101150512695, 'epoch': 0.2857142857142857})

# %% [markdown]
# # 모델 검증 및 평가

# %%
from tqdm import tqdm

# 검증 데이터셋을 사용하여 모델 출력 생성
generated_texts = []
for sample in tqdm(val_dataset):
    input_text = sample["text"]
    inputs = tokenizer(input_text, return_tensors="pt").to("cuda")
    outputs = base_model.generate(**inputs, max_new_tokens=50)
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    generated_texts.append(generated_text)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   0%|          | 1/200 [00:05<18:22,  5.54s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|          | 2/200 [00:12<20:29,  6.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 3/200 [00:16<17:39,  5.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 4/200 [00:21<17:03,  5.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▎         | 5/200 [00:25<15:49,  4.87s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 6/200 [00:28<13:51,  4.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▎         | 7/200 [00:32<13:06,  4.08s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▍         | 8/200 [00:36<12:29,  3.91s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▍         | 9/200 [00:38<10:41,  3.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▌         | 10/200 [00:40<09:29,  3.00s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▌         | 11/200 [00:42<08:40,  2.75s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▌         | 12/200 [00:44<08:05,  2.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▋         | 13/200 [00:47<08:01,  2.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 14/200 [00:49<07:55,  2.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 15/200 [00:52<07:30,  2.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 16/200 [00:54<07:15,  2.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 17/200 [00:56<07:01,  2.30s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▉         | 18/200 [00:58<06:56,  2.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|▉         | 19/200 [01:01<07:14,  2.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|█         | 20/200 [01:03<06:59,  2.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|█         | 21/200 [01:05<06:47,  2.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█         | 22/200 [01:07<06:36,  2.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 23/200 [01:09<06:29,  2.20s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 24/200 [01:12<06:53,  2.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▎        | 25/200 [01:15<06:53,  2.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 26/200 [01:17<06:39,  2.30s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▎        | 27/200 [01:19<06:29,  2.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▍        | 28/200 [01:21<06:21,  2.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▍        | 29/200 [01:23<06:26,  2.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  15%|█▌        | 30/200 [01:26<06:48,  2.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▌        | 31/200 [01:28<06:35,  2.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▌        | 32/200 [01:30<06:24,  2.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▋        | 33/200 [01:33<06:16,  2.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 34/200 [01:33<04:58,  1.80s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 35/200 [01:36<05:20,  1.94s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 36/200 [01:40<07:41,  2.81s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 37/200 [01:43<07:08,  2.63s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▉        | 38/200 [01:45<06:45,  2.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|█▉        | 39/200 [01:47<06:25,  2.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|██        | 40/200 [01:49<06:24,  2.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|██        | 41/200 [01:52<06:41,  2.52s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██        | 42/200 [01:54<06:23,  2.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 43/200 [01:57<06:07,  2.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 44/200 [01:57<04:25,  1.70s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▎       | 45/200 [01:59<04:43,  1.83s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 46/200 [02:01<04:56,  1.93s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▎       | 47/200 [02:04<05:35,  2.19s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▍       | 48/200 [02:06<05:37,  2.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▍       | 49/200 [02:08<05:29,  2.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▌       | 50/200 [02:10<05:26,  2.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▌       | 51/200 [02:13<05:24,  2.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▌       | 52/200 [02:15<05:31,  2.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▋       | 53/200 [02:18<05:54,  2.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 54/200 [02:20<05:41,  2.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 55/200 [02:22<05:31,  2.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 56/200 [02:24<05:22,  2.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 57/200 [02:26<05:18,  2.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▉       | 58/200 [02:29<05:33,  2.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|██▉       | 59/200 [02:31<05:30,  2.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|███       | 60/200 [02:34<05:19,  2.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|███       | 61/200 [02:36<05:13,  2.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███       | 62/200 [02:38<05:06,  2.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 63/200 [02:40<05:07,  2.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 64/200 [02:43<05:28,  2.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▎      | 65/200 [02:45<05:15,  2.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 66/200 [02:47<04:32,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▎      | 67/200 [02:49<04:35,  2.07s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▍      | 68/200 [02:51<04:38,  2.11s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▍      | 69/200 [02:53<04:44,  2.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  35%|███▌      | 70/200 [02:56<05:06,  2.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▌      | 71/200 [02:58<04:55,  2.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▌      | 72/200 [03:00<04:46,  2.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▋      | 73/200 [03:02<04:40,  2.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 74/200 [03:05<04:35,  2.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 75/200 [03:07<04:48,  2.30s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 76/200 [03:09<04:48,  2.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 77/200 [03:12<04:40,  2.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▉      | 78/200 [03:14<04:33,  2.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|███▉      | 79/200 [03:16<04:29,  2.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|████      | 80/200 [03:18<04:26,  2.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|████      | 81/200 [03:21<04:52,  2.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  41%|████      | 82/200 [03:23<04:41,  2.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 83/200 [03:26<04:29,  2.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 84/200 [03:28<04:22,  2.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▎     | 85/200 [03:30<04:16,  2.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 86/200 [03:32<04:20,  2.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▎     | 87/200 [03:35<04:35,  2.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▍     | 88/200 [03:37<04:25,  2.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▍     | 89/200 [03:39<04:15,  2.30s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▌     | 90/200 [03:42<04:09,  2.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▌     | 91/200 [03:44<04:04,  2.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▌     | 92/200 [03:47<04:19,  2.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▋     | 93/200 [03:49<04:17,  2.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  47%|████▋     | 94/200 [03:51<04:07,  2.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 95/200 [03:53<03:59,  2.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 96/200 [03:55<03:53,  2.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 97/200 [03:58<03:52,  2.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▉     | 98/200 [04:01<04:08,  2.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|████▉     | 99/200 [04:03<03:56,  2.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|█████     | 100/200 [04:05<03:47,  2.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|█████     | 101/200 [04:07<03:42,  2.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████     | 102/200 [04:09<03:38,  2.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 103/200 [04:12<03:44,  2.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 104/200 [04:14<03:51,  2.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▎    | 105/200 [04:17<03:41,  2.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  53%|█████▎    | 106/200 [04:19<03:33,  2.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▎    | 107/200 [04:21<03:28,  2.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▍    | 108/200 [04:23<03:23,  2.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▍    | 109/200 [04:26<03:38,  2.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▌    | 110/200 [04:28<03:36,  2.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▌    | 111/200 [04:30<03:27,  2.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▌    | 112/200 [04:33<03:21,  2.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▋    | 113/200 [04:35<03:16,  2.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 114/200 [04:37<03:13,  2.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▊    | 115/200 [04:40<03:27,  2.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 116/200 [04:42<03:17,  2.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 117/200 [04:44<03:10,  2.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  59%|█████▉    | 118/200 [04:46<03:05,  2.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|█████▉    | 119/200 [04:49<03:00,  2.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|██████    | 120/200 [04:51<03:06,  2.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|██████    | 121/200 [04:54<03:11,  2.42s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████    | 122/200 [04:56<03:02,  2.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 123/200 [04:58<02:56,  2.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 124/200 [05:00<02:50,  2.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▎   | 125/200 [05:02<02:45,  2.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 126/200 [05:05<02:57,  2.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▎   | 127/200 [05:07<02:50,  2.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▍   | 128/200 [05:10<02:43,  2.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▍   | 129/200 [05:12<02:39,  2.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  65%|██████▌   | 130/200 [05:14<02:35,  2.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▌   | 131/200 [05:16<02:36,  2.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▌   | 132/200 [05:19<02:44,  2.42s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▋   | 133/200 [05:21<02:37,  2.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 134/200 [05:23<02:31,  2.30s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 135/200 [05:25<02:25,  2.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 136/200 [05:28<02:20,  2.20s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 137/200 [05:30<02:28,  2.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▉   | 138/200 [05:33<02:27,  2.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|██████▉   | 139/200 [05:35<02:20,  2.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|███████   | 140/200 [05:37<02:15,  2.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|███████   | 141/200 [05:39<02:11,  2.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  71%|███████   | 142/200 [05:41<02:07,  2.20s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 143/200 [05:44<02:19,  2.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 144/200 [05:47<02:12,  2.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▎  | 145/200 [05:49<02:06,  2.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 146/200 [05:51<02:01,  2.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  74%|███████▎  | 147/200 [05:53<01:58,  2.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  74%|███████▍  | 148/200 [05:55<01:58,  2.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  74%|███████▍  | 149/200 [05:58<02:03,  2.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  75%|███████▌  | 150/200 [06:00<01:58,  2.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▌  | 151/200 [06:02<01:52,  2.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▌  | 152/200 [06:05<01:48,  2.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▋  | 153/200 [06:07<01:44,  2.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 154/200 [06:10<01:52,  2.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 155/200 [06:12<01:46,  2.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 156/200 [06:14<01:41,  2.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 157/200 [06:16<01:36,  2.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  79%|███████▉  | 158/200 [06:18<01:34,  2.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|███████▉  | 159/200 [06:21<01:33,  2.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|████████  | 160/200 [06:23<01:34,  2.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|████████  | 161/200 [06:26<01:29,  2.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████  | 162/200 [06:28<01:25,  2.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 163/200 [06:30<01:21,  2.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 164/200 [06:32<01:19,  2.19s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▎ | 165/200 [06:35<01:24,  2.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 166/200 [06:37<01:20,  2.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▎ | 167/200 [06:39<01:15,  2.30s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▍ | 168/200 [06:41<01:11,  2.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▍ | 169/200 [06:43<01:08,  2.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  85%|████████▌ | 170/200 [06:46<01:07,  2.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▌ | 171/200 [06:49<01:09,  2.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▌ | 172/200 [06:51<01:04,  2.32s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▋ | 173/200 [06:53<01:01,  2.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 174/200 [06:55<00:58,  2.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 175/200 [06:57<00:55,  2.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 176/200 [07:00<00:57,  2.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 177/200 [07:02<00:54,  2.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▉ | 178/200 [07:04<00:50,  2.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|████████▉ | 179/200 [07:07<00:47,  2.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|█████████ | 180/200 [07:09<00:44,  2.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|█████████ | 181/200 [07:11<00:42,  2.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████ | 182/200 [07:14<00:43,  2.42s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 183/200 [07:16<00:39,  2.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 184/200 [07:18<00:36,  2.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▎| 185/200 [07:20<00:33,  2.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 186/200 [07:22<00:30,  2.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▎| 187/200 [07:25<00:29,  2.30s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▍| 188/200 [07:27<00:28,  2.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▍| 189/200 [07:30<00:25,  2.32s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▌| 190/200 [07:32<00:22,  2.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▌| 191/200 [07:34<00:20,  2.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▌| 192/200 [07:36<00:17,  2.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▋| 193/200 [07:39<00:17,  2.48s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 194/200 [07:41<00:14,  2.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 195/200 [07:44<00:11,  2.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 196/200 [07:46<00:09,  2.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 197/200 [07:48<00:06,  2.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▉| 198/200 [07:50<00:04,  2.32s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 100%|█████████▉| 199/200 [07:53<00:02,  2.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 100%|██████████| 200/200 [07:55<00:00,  2.38s/it]

# %% [markdown]
# sacrebleu 라이브러리 설치

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.4.3-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.2 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2024.9.11)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (1.26.4)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (5.3.0)
# Downloading sacrebleu-2.4.3-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 9.4 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-2.10.1 sacrebleu-2.4.3

# %% [markdown]
# BLEU 스코어 계산

# %%
import sacrebleu

# BLEU 스코어 계산
bleu = sacrebleu.corpus_bleu(predictions, [references])
print(f"BLEU score: {bleu.score}")
# Out:
# BLEU score: 0.9616295075150939
